# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('ebola.csv')

# %%
df.head()
# Out:
#          Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0    1/5/2015  289        2776.0            NaN            10030.0
# 1    1/4/2015  288        2775.0            NaN             9780.0
# 2    1/3/2015  287        2769.0         8166.0             9722.0
# 3    1/2/2015  286           NaN         8157.0                NaN
# 4  12/31/2014  284        2730.0         8115.0             9633.0
#
#    Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali  \
# 0            NaN            NaN                 NaN          NaN         NaN
# 1            NaN            NaN                 NaN          NaN         NaN
# 2            NaN            NaN                 NaN          NaN         NaN
# 3            NaN            NaN                 NaN          NaN         NaN
# 4            NaN            NaN                 NaN          NaN         NaN
#
#    Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  Deaths_Nigeria  \
# ...

# %%
df.tail()
# Out:
#           Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 117  3/27/2014    5         103.0            8.0                6.0
# 118  3/26/2014    4          86.0            NaN                NaN
# 119  3/25/2014    3          86.0            NaN                NaN
# 120  3/24/2014    2          86.0            NaN                NaN
# 121  3/22/2014    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 117            NaN            NaN                 NaN          NaN
# 118            NaN            NaN                 NaN          NaN
# 119            NaN            NaN                 NaN          NaN
# 120            NaN            NaN                 NaN          NaN
# 121            NaN            NaN                 NaN          NaN
#
#      Cases_Mali  Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  \
# 117         NaN           66.0             6.0                 5.0
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=122, step=1)

# %%
df.values
# Out:
# array([['1/5/2015', 289, 2776.0, ..., nan, nan, nan],
#        ['1/4/2015', 288, 2775.0, ..., nan, nan, nan],
#        ['1/3/2015', 287, 2769.0, ..., nan, nan, nan],
#        ...,
#        ['3/25/2014', 3, 86.0, ..., nan, nan, nan],
#        ['3/24/2014', 2, 86.0, ..., nan, nan, nan],
#        ['3/22/2014', 0, 49.0, ..., nan, nan, nan]], dtype=object)

# %%
df.columns
# Out:
# Index(['Date', 'Day', 'Cases_Guinea', 'Cases_Liberia', 'Cases_SierraLeone',
#        'Cases_Nigeria', 'Cases_Senegal', 'Cases_UnitedStates', 'Cases_Spain',
#        'Cases_Mali', 'Deaths_Guinea', 'Deaths_Liberia', 'Deaths_SierraLeone',
#        'Deaths_Nigeria', 'Deaths_Senegal', 'Deaths_UnitedStates',
#        'Deaths_Spain', 'Deaths_Mali'],
#       dtype='object')

# %%
df
# Out:
#            Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0      1/5/2015  289        2776.0            NaN            10030.0
# 1      1/4/2015  288        2775.0            NaN             9780.0
# 2      1/3/2015  287        2769.0         8166.0             9722.0
# 3      1/2/2015  286           NaN         8157.0                NaN
# 4    12/31/2014  284        2730.0         8115.0             9633.0
# ..          ...  ...           ...            ...                ...
# 117   3/27/2014    5         103.0            8.0                6.0
# 118   3/26/2014    4          86.0            NaN                NaN
# 119   3/25/2014    3          86.0            NaN                NaN
# 120   3/24/2014    2          86.0            NaN                NaN
# 121   3/22/2014    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# ...

# %%
ebola=df.melt(id_vars=['Date','Day'],var_name= 'cd_country', value_name='count')
ebola.head()
# Out:
#          Date  Day    cd_country   count
# 0    1/5/2015  289  Cases_Guinea  2776.0
# 1    1/4/2015  288  Cases_Guinea  2775.0
# 2    1/3/2015  287  Cases_Guinea  2769.0
# 3    1/2/2015  286  Cases_Guinea     NaN
# 4  12/31/2014  284  Cases_Guinea  2730.0

# %%
'hello Wor ld'.split(' ')
# Out:
# ['hello', 'Wor', 'ld']

# %%
ebola['cd_country']
# Out:
# 0       Cases_Guinea
# 1       Cases_Guinea
# 2       Cases_Guinea
# 3       Cases_Guinea
# 4       Cases_Guinea
#             ...
# 1947     Deaths_Mali
# 1948     Deaths_Mali
# 1949     Deaths_Mali
# 1950     Deaths_Mali
# 1951     Deaths_Mali
# Name: cd_country, Length: 1952, dtype: object

# %%
ebola_split=ebola['cd_country'].str.split('_', expand=True)

# %%
ebola_split
# Out:
#            0       1
# 0      Cases  Guinea
# 1      Cases  Guinea
# 2      Cases  Guinea
# 3      Cases  Guinea
# 4      Cases  Guinea
# ...      ...     ...
# 1947  Deaths    Mali
# 1948  Deaths    Mali
# 1949  Deaths    Mali
# 1950  Deaths    Mali
# 1951  Deaths    Mali
#
# [1952 rows x 2 columns]

# %%
ebola[['status','country']]=ebola_split

# %%
ebola
# Out:
#             Date  Day    cd_country   count      Cd country  status
# 0       1/5/2015  289  Cases_Guinea  2776.0   Cases  Guinea   Cases
# 1       1/4/2015  288  Cases_Guinea  2775.0   Cases  Guinea   Cases
# 2       1/3/2015  287  Cases_Guinea  2769.0   Cases  Guinea   Cases
# 3       1/2/2015  286  Cases_Guinea     NaN   Cases  Guinea   Cases
# 4     12/31/2014  284  Cases_Guinea  2730.0   Cases  Guinea   Cases
# ...          ...  ...           ...     ...     ...     ...     ...
# 1947   3/27/2014    5   Deaths_Mali     NaN  Deaths    Mali  Deaths
# 1948   3/26/2014    4   Deaths_Mali     NaN  Deaths    Mali  Deaths
# 1949   3/25/2014    3   Deaths_Mali     NaN  Deaths    Mali  Deaths
# 1950   3/24/2014    2   Deaths_Mali     NaN  Deaths    Mali  Deaths
# 1951   3/22/2014    0   Deaths_Mali     NaN  Deaths    Mali  Deaths
#
# [1952 rows x 7 columns]

# %%
weather=pd.read_csv('weather.csv')

# %%
weather.head()
# Out:
#         id  year  month element  d1    d2    d3  d4    d5  d6  ...  d22   d23  \
# 0  MX17004  2010      1    tmax NaN   NaN   NaN NaN   NaN NaN  ...  NaN   NaN
# 1  MX17004  2010      1    tmin NaN   NaN   NaN NaN   NaN NaN  ...  NaN   NaN
# 2  MX17004  2010      2    tmax NaN  27.3  24.1 NaN   NaN NaN  ...  NaN  29.9
# 3  MX17004  2010      2    tmin NaN  14.4  14.4 NaN   NaN NaN  ...  NaN  10.7
# 4  MX17004  2010      3    tmax NaN   NaN   NaN NaN  32.1 NaN  ...  NaN   NaN
#
#    d24  d25  d26  d27  d28  d29   d30  d31
# 0  NaN  NaN  NaN  NaN  NaN  NaN  27.8  NaN
# 1  NaN  NaN  NaN  NaN  NaN  NaN  14.5  NaN
# 2  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN
# 3  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN
# 4  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN
#
# [5 rows x 35 columns]

# %%
weather_long=weather.melt(id_vars=['id','year','month','element'],var_name='day',value_name='Amount')

# %%
weather_long.head()
# Out:
#         id  year  month element day  Amount
# 0  MX17004  2010      1    tmax  d1     NaN
# 1  MX17004  2010      1    tmin  d1     NaN
# 2  MX17004  2010      2    tmax  d1     NaN
# 3  MX17004  2010      2    tmin  d1     NaN
# 4  MX17004  2010      3    tmax  d1     NaN

# %%
weather_long.pivot(index=['id','year','month','day'], columns='element',values='Amount').reset_index()
# Out:
# element       id  year  month  day  tmax  tmin
# 0        MX17004  2010      1   d1   NaN   NaN
# 1        MX17004  2010      1  d10   NaN   NaN
# 2        MX17004  2010      1  d11   NaN   NaN
# 3        MX17004  2010      1  d12   NaN   NaN
# 4        MX17004  2010      1  d13   NaN   NaN
# ..           ...   ...    ...  ...   ...   ...
# 336      MX17004  2010     12   d5   NaN   NaN
# 337      MX17004  2010     12   d6  27.8  10.5
# 338      MX17004  2010     12   d7   NaN   NaN
# 339      MX17004  2010     12   d8   NaN   NaN
# 340      MX17004  2010     12   d9   NaN   NaN
#
# [341 rows x 6 columns]

# %%
10_000_000_000
# Out:
# 10000000000

# %%
tbl3['population']=tbl3['rate'].str.split['/'].str.get(1)

# %%
[
    1,
   #2,
    3a
    
]
# Out:
# [1, 3]
