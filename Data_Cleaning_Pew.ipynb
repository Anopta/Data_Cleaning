# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('pew.csv')

# %%
df.head()
# Out:
#   Weight variable recommended for use in all analyses   Unique ID  \
# 0                                             weight       psraid
# 1                                               11.0   10000047.0
# 2                                               13.0   10000065.0
# 3                                               37.0   10000070.0
# 4                                              188.0   10000103.0
#
#   Former Religion Target Groups Former Religion Target Groups_labels  \
# 0                       FRMREL2                                  NaN
# 1                       10000.0                             CATHOLIC
# 2                       10000.0                             CATHOLIC
# 3                       10000.0                             CATHOLIC
# 4                           2.0                            METHODIST
#
#   Current Religion Target Groups      Current Religion Target Groups_labels  \
# ...

# %%
df.columns
# Out:
# Index(['Weight variable recommended for use in all analyses', 'Unique ID',
#        'Former Religion Target Groups', 'Former Religion Target Groups_labels',
#        'Current Religion Target Groups',
#        'Current Religion Target Groups_labels', 'Converts', 'Converts_labels',
#        'Quota groups', 'Quota groups_labels',
#        ...
#        'Q.22h Please tell me which, if any, you have ever identified with at any point in your life?  Have you ever been --Jewis',
#        'Q.22h Please tell me which, if any, you have ever identified with at any point in your life?  Have you ever been --Jewis_labels',
#        'Q.22h2 Please tell me which, if any, you have ever identified with at any point in your life?  Have you ever been --just',
#        'Q.22h2 Please tell me which, if any, you have ever identified with at any point in your life?  Have you ever been --just_labels',
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=2868, step=1)

# %%
df.values
# Out:
# array([['weight', 'psraid', 'FRMREL2', ..., nan, 'q22l', nan],
#        ['11.0', '10000047.0', '10000.0', ..., 'No', '2.0', 'No'],
#        ['13.0', '10000065.0', '10000.0', ..., 'No', '2.0', 'No'],
#        ...,
#        ['28.0', '90000718.0', '10000.0', ..., 'No', '2.0', 'No'],
#        ['46.0', '90000730.0', '10000.0', ..., 'No', '2.0', 'No'],
#        ['44.0', '90000777.0', '10000.0', ..., 'No', '2.0', 'No']],
#       dtype=object)

# %%
New=pd.melt(
df,
id_vars=['Unique ID']

)

# %%
New.head()
# Out:
#     Unique ID                                           variable   value
# 0      psraid  Weight variable recommended for use in all ana...  weight
# 1  10000047.0  Weight variable recommended for use in all ana...    11.0
# 2  10000065.0  Weight variable recommended for use in all ana...    13.0
# 3  10000070.0  Weight variable recommended for use in all ana...    37.0
# 4  10000103.0  Weight variable recommended for use in all ana...   188.0

# %%
New
# Out:
#          Unique ID                                           variable   value
# 0           psraid  Weight variable recommended for use in all ana...  weight
# 1       10000047.0  Weight variable recommended for use in all ana...    11.0
# 2       10000065.0  Weight variable recommended for use in all ana...    13.0
# 3       10000070.0  Weight variable recommended for use in all ana...    37.0
# 4       10000103.0  Weight variable recommended for use in all ana...   188.0
# ...            ...                                                ...     ...
# 599407  90000547.0  Q.22l Please tell me which, if any, you have e...     NaN
# 599408  90000666.0  Q.22l Please tell me which, if any, you have e...     NaN
# 599409  90000718.0  Q.22l Please tell me which, if any, you have e...      No
# 599410  90000730.0  Q.22l Please tell me which, if any, you have e...      No
# 599411  90000777.0  Q.22l Please tell me which, if any, you have e...      No
#
# [599412 rows x 3 columns]

# %%
df
# Out:
#      Weight variable recommended for use in all analyses   Unique ID  \
# 0                                                weight       psraid
# 1                                                  11.0   10000047.0
# 2                                                  13.0   10000065.0
# 3                                                  37.0   10000070.0
# 4                                                 188.0   10000103.0
# ...                                                 ...          ...
# 2863                                              442.0   90000547.0
# 2864                                              386.0   90000666.0
# 2865                                               28.0   90000718.0
# 2866                                               46.0   90000730.0
# 2867                                               44.0   90000777.0
#
#      Former Religion Target Groups Former Religion Target Groups_labels  \
# ...

# %%
df.shape
# Out:
# (2868, 210)

# %%
New.shape
# Out:
# (599412, 3)
